# %%
import h5py
import matplotlib.pyplot as plt
import os, sys

# %%
data_path = '../output/x01_π/00015_x01_lagos.h5'

# %%
result = []
with h5py.File(data_path, 'r') as hf:
    data = hf.get('uks')
    result = data[...]

print(result.shape)
# Out:
# (5, 1, 1, 144)

# %%
data1 = result[0][0]
data2 = result[4][0]

# %%
import numpy as np
data = result[3][0]
dt = 32/144
ops_max_amp = [2 * np.pi * 0.073036776]
Hnames = ['x']
for jj in range (len(data1)):
            plt.scatter(np.array([dt * ii for ii in range(144)]), np.array(ops_max_amp[jj] * data1[jj,:]), color='red', marker='o', label='u' + Hnames[jj] + '0')
            plt.scatter(np.array([dt * ii for ii in range(144)]), np.array(ops_max_amp[jj] * data2[jj,:]), color='green', marker='x',label='u' + Hnames[jj] + '4')
    
plt.xlim(0, 32)
# plt.ylim(-0.25, 0.25)
# Out:
# (0.0, 32.0)

# %%
x = np.array([dt * ii for ii in range(144)])
# y = np.array(-abs(ops_max_amp[0] * data[0, :]))
y = np.array(ops_max_amp[0] * data[0, :])

# %%
plt.plot(x,-abs(y))
