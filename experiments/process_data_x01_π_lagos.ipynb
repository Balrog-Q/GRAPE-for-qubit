# %%
import h5py
import matplotlib.pyplot as plt
import os, sys

# %%
data_path = '../output/x01_π/00009_x01_lagos.h5'

# %%
result = []
with h5py.File(data_path, 'r') as hf:
    data = hf.get('uks')
    result = data[...]

print(result.shape)
# Out:
# (54, 1, 1, 144)

# %%
data = result[53][0]

# %%
import numpy as np
dt = 32/144
ops_max_amp = [2 * np.pi * 0.073036776]
Hnames = ['x']
for jj in range (len(data)):
            plt.plot(np.array([dt * ii for ii in range(144)]), np.array(ops_max_amp[jj] * data[jj,:]), label='u' + Hnames[jj])
    
plt.xlim(10, 20)
plt.ylim(-0.25, 0.25)
# Out:
# (-0.25, 0.25)

# %%
x = np.array([dt * ii for ii in range(144)])
# y = np.array(-abs(ops_max_amp[0] * data[0, :]))
y = np.array(ops_max_amp[0] * data[0, :])

# %%
plt.plot(x,-abs(y))
